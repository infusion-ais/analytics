# %%
# !pip install yfinance
# !pip install yahoofinancials

# %%
import yfinance as yf
from yahoofinancials import YahooFinancials

# %%
ticker = 'TTM'
yahoo_financials = YahooFinancials(ticker)
stock = yf.download(tickers=f"{ticker}", start="2020-01-01", end="2022-03-30", progress=False)
stock.tail()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2022-03-23  28.049999  28.570000  28.049999  28.150000  28.150000   608500
# 2022-03-24  28.330000  28.650000  28.170000  28.580000  28.580000   685600
# 2022-03-25  28.330000  28.410000  28.000000  28.400000  28.400000   505700
# 2022-03-28  28.440001  28.700001  28.270000  28.540001  28.540001   329900
# 2022-03-29  28.990000  29.590000  28.990000  29.150000  29.150000  1183500

# %%
ticker = yf.Ticker(f"{ticker}")
ticker.info
# Out:
# {'52WeekChange': 0.50395644,
#  'SandP52WeekChange': -0.0445475,
#  'address1': 'Shivasagar Estate',
#  'address2': 'A Block Dr. Annie Besant Road Worli',
#  'algorithm': None,
#  'annualHoldingsTurnover': None,
#  'annualReportExpenseRatio': None,
#  'ask': 0,
#  'askSize': 1100,
#  'averageDailyVolume10Day': 614700,
#  'averageVolume': 655024,
#  'averageVolume10days': 614700,
#  'beta': 2.08547,
#  'beta3Year': None,
#  'bid': 0,
#  'bidSize': 800,
#  'bookValue': 581.865,
#  'category': None,
#  'circulatingSupply': None,
#  'city': 'Mumbai',
#  'coinMarketCapLink': None,
#  'companyOfficers': [],
#  'country': 'India',
#  'currency': 'USD',
#  'currentPrice': 30.41,
#  'currentRatio': None,
#  'dateShortInterest': 1659052800,
#  'dayHigh': 30.46,
#  'dayLow': 29.86,
#  'debtToEquity': 297.724,
#  'dividendRate': None,
#  'dividendYield': None,
#  'earningsGrowth': None,
#  'earningsQuarterlyGrowth': None,
#  'ebitda': 119108452352,
#  'ebitdaMargins': 0.041939996,
# ...

# %%
# Obtain income statements
yahoo_financials.get_financial_stmts('annual', 'income')
# Out:
# {'incomeStatementHistory': {'TTM': [{'2022-03-31': {'costOfRevenue': 1651660300000,
#      'discontinuedOperations': None,
#      'ebit': 21022400000,
#      'effectOfAccountingCharges': None,
#      'extraordinaryItems': None,
#      'grossProfit': 1132875900000,
#      'incomeBeforeTax': -70774700000,
#      'incomeTaxExpense': 42312900000,
#      'interestExpense': -84159600000,
#      'minorityInterest': 42710600000,
#      'netIncome': -114414700000,
#      'netIncomeApplicableToCommonShares': -114414700000,
#      'netIncomeFromContinuingOps': -113087600000,
#      'nonRecurring': None,
#      'operatingIncome': 21022400000,
#      'otherItems': None,
#      'otherOperatingExpenses': 414679900000,
#      'researchDevelopment': 92095000000,
#      'sellingGeneralAdministrative': 356721700000,
#      'totalOperatingExpenses': 2763513800000,
#      'totalOtherIncomeExpenseNet': -91797100000,
#      'totalRevenue': 2784536200000}},
# ...
